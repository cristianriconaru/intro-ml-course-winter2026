# %% [markdown]
# <a href="https://colab.research.google.com/github/cristianriconaru/intro-ml-course-winter2026/blob/main/Tutorial_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Section 1
# ## Part A

# %%
print("Hello World")
# Out:
# Hello World
